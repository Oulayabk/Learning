# %% [markdown]
# # Matrix and vectors

# %%
import numpy as np 
from numpy.linalg import inv
A = np.array([[4,8], [3,7]])
B = np.array([[1,0], [5,2]])

np.dot(A,B)
# Out:
# array([[44, 16],
#        [38, 14]])

# %%
format(A.shape)
# Out:
# '(2, 2)'

# %%
A.transpose()
# Out:
# array([[4, 3],
#        [8, 7]])

# %%
I= inv(A)
I
# Out:
# array([[ 1.75, -2.  ],
#        [-0.75,  1.  ]])

# %%
np.dot(A,I)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %% [markdown]
# # matrix and machine learning

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread(r"C:\Users\Oulaya\Desktop\grayscale_img.jfif")
plt.imshow(img)

# %%
img
# Out:
# array([[[ 44,  12,  17],
#         [ 44,  12,  17],
#         [ 44,  12,  17],
#         ...,
#         [169, 178, 193],
#         [169, 178, 193],
#         [168, 177, 192]],
#
#        [[ 44,  12,  17],
#         [ 44,  12,  17],
#         [ 44,  12,  17],
#         ...,
#         [169, 178, 193],
#         [168, 177, 192],
#         [168, 177, 192]],
#
#        [[ 44,  12,  17],
#         [ 44,  12,  17],
#         [ 44,  12,  17],
#         ...,
#         [168, 177, 192],
#         [168, 177, 192],
#         [168, 177, 192]],
#
#        ...,
#
#        [[139, 137, 148],
#         [139, 137, 148],
#         [139, 137, 148],
#         ...,
#         [187, 188, 190],
#         [187, 188, 190],
#         [187, 188, 190]],
#
#        [[139, 137, 148],
#         [139, 137, 148],
#         [139, 137, 148],
#         ...,
#         [187, 188, 190],
#         [187, 188, 190],
#         [187, 188, 190]],
#
#        [[139, 137, 148],
#         [139, 137, 148],
#         [139, 137, 148],
# ...

# %%
img.shape
# Out:
# (183, 275, 3)
